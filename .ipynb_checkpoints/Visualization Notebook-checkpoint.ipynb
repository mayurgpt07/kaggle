# %%
from sklearn import linear_model
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import statsmodels.formula.api as sm


train_data = pd.read_csv("./data/kc_house_data.csv", sep = ",", header = 0)

#Start PreProcessing 
train_data['dateInFormat'] = train_data['date'].apply(lambda x: x[0:8])
train_data['dateInFormat'] = train_data['dateInFormat'].apply(lambda x: datetime.strptime(x, '%Y%m%d'))
train_data['YearSold'] = train_data['dateInFormat'].apply(lambda x: int(x.year))
train_data['HomeAgeinYear'] = train_data['YearSold'] - train_data['yr_built']
#Check the correlation matrix with price


#train_data.corr().loc[:,'id':'price'].style.background_gradient(cmap='coolwarm', axis=None)

#pd.plotting.scatter_matrix(train_data.loc[:,'price':'floors'], alpha = 0.2, figsize = (20, 20), diagonal = 'kde')
#plt.show()

train_data['Log_sqftlot'] = train_data['sqft_lot'].apply(lambda x: np.log(x))
train_data['Log_price'] = train_data['price'].apply(lambda x: np.log(x))
train_data['Log_sqftlot15'] = train_data['sqft_lot15'].apply(lambda x: np.log(x))

#plt.hist(train_data['sqft_lot'], color = "red")
#plt.hist(train_data['sqft_lot'], color = "skyblue")
#plt.hist(train_data['price'], color = 'red')
#plt.hist(train_data['sqft_living'], color = 'brown')
#plt.hist(train_data['CubeRoot_sqftBasement'], color = 'green')
#plt.show()

columnsToTrain = ['bedrooms', 'bathrooms', 'Log_sqftLiving', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'Log_sqftAbove', 'HomeAgeinYear',
       'lat', 'long', 'sqft_living15','Log_sqftlot15',
       'Log_sqftlot']


X, y = train_data.loc[:, columnsToTrain], train_data.loc[:, 'Log_price']

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, y, test_size = 0.30)

train_data.corr().loc[:,'Log_sqftlot':'Log_price'].style.background_gradient(cmap='coolwarm', axis=None)
#model = LinearRegression()

#fittedModel = model.fit(X_train, Y_train)

#print(fittedModel.score(X_train, Y_train))
#print(fittedModel.coef_)


#formuala = 'Log_price ~ bedrooms+bathrooms+Log_sqftLiving+Log_sqftlot+floors+waterfront+view+condition+grade+Log_sqftAbove+HomeAgeinYear+lat+long+sqft_living15+Log_sqftlot15'
#statisticalModel = sm.ols(formuala, data = train_data)
#statsfitted = statisticalModel.fit()
#print(statsfitted.summary())

#print(fittedModel.predict(X_test))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# <style  type="text/css" >
#     #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow0_col0 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow0_col1 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow1_col0 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow1_col1 {
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow2_col0 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow2_col1 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow3_col0 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow3_col1 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow4_col0 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow4_col1 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow5_col0 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow5_col1 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow6_col0 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow6_col1 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow7_col0 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow7_col1 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow8_col0 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow8_col1 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow9_col0 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow9_col1 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow10_col0 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow10_col1 {
#             background-color:  #f29274;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow11_col0 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow11_col1 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow12_col0 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow12_col1 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow13_col0 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow13_col1 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow14_col0 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow14_col1 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow15_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow15_col1 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow16_col0 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow16_col1 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow17_col0 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow17_col1 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow18_col0 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow18_col1 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow19_col0 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow19_col1 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow20_col0 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow20_col1 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow21_col0 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow21_col1 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow22_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow22_col1 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow23_col0 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow23_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow24_col0 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow24_col1 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }</style><table id="T_a6b95728_f0a5_11e9_a6dc_4889e7b024de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Log_sqftlot</th>        <th class="col_heading level0 col1" >Log_price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a6b95728_f0a5_11e9_a6dc_4889e7b024delevel0_row0" class="row_heading level0 row0" >id</th>
#                         <td id="T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow0_col0" class="data row0 col0" >-0.149975</td>
#                         <td id="T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow0_col1" class="data row0 col1" >-0.00381909</td>
#             </tr>
#             <tr>
#                         <th id="T_a6b95728_f0a5_11e9_a6dc_4889e7b024delevel0_row1" class="row_heading level0 row1" >price</th>
#                         <td id="T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow1_col0" class="data row1 col0" >0.161318</td>
#                         <td id="T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow1_col1" class="data row1 col1" >0.891654</td>
#             </tr>
#             <tr>
#                         <th id="T_a6b95728_f0a5_11e9_a6dc_4889e7b024delevel0_row2" class="row_heading level0 row2" >bedrooms</th>
#                         <td id="T_a6b95728_f0a5_11e9_a6dc_4889e7b024derow2_col0" cl
