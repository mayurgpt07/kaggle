# %%
from sklearn import linear_model
from sklearn import model_selection
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import statsmodels.formula.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
import math
import reverse_geocoder as rgc
import pprint as pp

train_data = pd.read_csv("./data/kc_house_data.csv", sep = ",", header = 0)

#Start PreProcessing
#Changing the date format to get the year 
train_data['dateInFormat'] = train_data['date'].apply(lambda x: x[0:8])
train_data['dateInFormat'] = train_data['dateInFormat'].apply(lambda x: datetime.strptime(x, '%Y%m%d'))
#The year in which the propert was sold
train_data['YearSold'] = train_data['dateInFormat'].apply(lambda x: int(x.year))

#Since the value of Built Year and Selling Year is large, its good to normalize the value of different variables to similar range

#We derive the Time since its built
train_data['HomeAgeinYear'] = train_data['YearSold'] - train_data['yr_built']

#We derive the Time after which it was renovated
train_data['RenovatedafterYears'] = train_data['yr_renovated'] - train_data['yr_built']

#Creating WaterFront as a dummy variable
train_data['IsRenovated'] = train_data['waterfront'].apply(lambda x: 1 if x > 0 else -1)


#pd.plotting.scatter_matrix(train_data.loc[:,'price':'floors'], alpha = 0.2, figsize = (20, 20), diagonal = 'kde')
#plt.show()


#Lot of variables are not specifically normally distributed. Therefore transforming them using log(Base e) transform
train_data['Log_sqftlot'] = train_data['sqft_lot'].apply(lambda x: np.log(x))
train_data['Log_price'] = train_data['price'].apply(lambda x: np.log(x))
train_data['Log_sqftlot15'] = train_data['sqft_lot15'].apply(lambda x: np.log(x))
train_data['Log_sqftLiving'] = train_data['sqft_living'].apply(lambda x: np.log(x))

#GeoLocation to be added into the picture. Try to convert Latitude and Longitude to location names
for i in range(0, len(train_data['lat'])):
	coordiantes = (train_data.loc[i,'lat'], train_data.loc[i,'long'])
	train_data.loc[i, 'Location'] = rgc.search(coordiantes, mode = 1)[0].get('name')


mappingDictionary = {}

for k in train_data.Location.unique():
	#print(train_data[train_data['Location'] == k].price.mean())
	mappingDictionary[k] = train_data[train_data['Location'] == k].price.mean()

train_data['LocationMapping'] = train_data['Location'].apply(lambda x: mappingDictionary.get(x))

meanOfLocation = train_data['LocationMapping'].mean()
standardDeviationLocation = train_data['LocationMapping'].std()

train_data['LocationMapping'] = train_data['LocationMapping'].apply(lambda x: ((x-meanOfLocation)/standardDeviationLocation))

train_data['LivingSpaceAvailable'] = train_data['sqft_living']/train_data['sqft_lot']
train_data['NeighbourSpace'] = train_data['sqft_living15']/train_data['sqft_lot15']
train_data['Log_LivingSpaceAvailable'] = train_data['LivingSpaceAvailable'].apply(lambda x: np.log(x))
train_data['Log_NeighbourSpace'] = train_data['NeighbourSpace'].apply(lambda x: np.log(x))
#np.savetxt('File.csv', train_data['NeighbourhoodLiving'])

#The Value of VIF tells that there is a collinearity between the Living space and above space. Assuming that both will be same if basement is not there.
#Therefore removing basement values and converting it into a variable to express the presence or absence of it
train_data['IsBasementThere'] = train_data['sqft_basement'].apply(lambda x: 1 if x >= 1 else -1)
#plt.hist(train_data['sqft_lot'], color = "red")
#plt.hist(train_data['grade'], color = "skyblue")
#plt.show()


#Check the correlation matrix with price (the below command only works with jupyter notebook or other software having HTML support)
train_data.corr().loc[:,['price','Log_price']].style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow0_col0 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow0_col1 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow1_col1 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow2_col0 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow2_col1 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow3_col0 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow3_col1 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow4_col0 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow4_col1 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow5_col0 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow5_col1 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow6_col0 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow6_col1 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow7_col0 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow7_col1 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow8_col0 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow8_col1 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow9_col0 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow9_col1 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow10_col0 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow10_col1 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow11_col0 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow11_col1 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow12_col0 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow12_col1 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow13_col0 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow13_col1 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow14_col0 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow14_col1 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow15_col0 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow15_col1 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow16_col0 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow16_col1 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow17_col0 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow17_col1 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow18_col0 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow18_col1 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow19_col0 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow19_col1 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow20_col0 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow20_col1 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow21_col0 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow21_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow22_col0 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow22_col1 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow23_col0 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow23_col1 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow24_col0 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow24_col1 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow25_col0 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow25_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow26_col0 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow26_col1 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow27_col0 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow27_col1 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow28_col0 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow28_col1 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow29_col0 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_9eb10ce6_07fa_11ea_a9e1_4889e7b024derow29_col1 {
#             background-color:  #
