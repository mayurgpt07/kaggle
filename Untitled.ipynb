# %%
from sklearn import linear_model
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import statsmodels.formula.api as sm


train_data = pd.read_csv("./data/kc_house_data.csv", sep = ",", header = 0)

#Start PreProcessing 
train_data['dateInFormat'] = train_data['date'].apply(lambda x: x[0:8])
train_data['dateInFormat'] = train_data['dateInFormat'].apply(lambda x: datetime.strptime(x, '%Y%m%d'))

#print(train_data)
#Check the correlation matrix with price
#train_data.corr().loc[:,'id':'price'].style.background_gradient(cmap='coolwarm', axis=None)

#pd.plotting.scatter_matrix(train_data.loc[:,'price':'floors'], alpha = 0.2, figsize = (20, 20), diagonal = 'kde')
#plt.show()

train_data['Log_sqftlot'] = train_data['sqft_lot'].apply(lambda x: np.log(x))
train_data['Log_price'] = train_data['price'].apply(lambda x: np.log(x))
train_data['Log_sqftlot15'] = train_data['sqft_lot15'].apply(lambda x: np.log(x))

#print(train_data.columns)
#plt.hist(train_data['sqft_lot'], color = "red")
#plt.hist(train_data['sqft_lot'], color = "skyblue")
#plt.hist(train_data['price'], color = 'red')
#plt.hist(train_data['sqft_living'], color = 'brown')
#plt.hist(train_data['Log_sqftlot15'], color = 'skyblue')
#plt.hist(train_data['grade'], color = 'green')
#plt.show()

train_data.corr().loc[:,'id':'price'].style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow0_col1 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow1_col0 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow2_col0 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow2_col1 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow3_col0 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow3_col1 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow4_col0 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow4_col1 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow5_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow5_col1 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow6_col0 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow6_col1 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow7_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow7_col1 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow8_col0 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow8_col1 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow9_col0 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow9_col1 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow10_col0 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow10_col1 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow11_col0 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow11_col1 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow12_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow12_col1 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow13_col0 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow13_col1 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow14_col0 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow14_col1 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow15_col0 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow15_col1 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow16_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow16_col1 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow17_col0 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow17_col1 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow18_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow18_col1 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow19_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow19_col1 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow20_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow20_col1 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow21_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow21_col1 {
#             background-color:  #d55042;
#             color:  #000000;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow22_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b0d5fc98_f050_11e9_88dd_4889e7b024derow22_col1 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }</style><table id="T_b0d5fc98_f050_11e9_88dd_4889e7b024de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0d5fc98_f050_11e9_88dd_4889e7b024delevel0_row0" class="row_heading level0 row0" >id</th>
#                         <td id="T_b0d5fc98_f050_11e9_88dd_4889e7b024derow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b0d5fc98_f050_11e9_88dd_4889e7b024derow0_col1" class="data row0 col1" >-0.0167622</td>
#             </tr>
#             <tr>
#                         <th id="T_b0d5fc98_f050_11e9_88dd_4889e7b024delevel0_row1" class="row_heading level0 row1" >price</th>
#                         <td id="T_b0d5fc98_f050_11e9_88dd_4889e7b024derow1_col0" class="data row1 col0" >-0.0167622</td>
#                         <td id="T_b0d5fc98_f050_11e9_88dd_4889e7b024derow1_col1" class="data row1 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_b0d5fc98_f050_11e9_88dd_4889e7b024delevel0_row2" class="row_heading level0 row2" >bedrooms</th>
#                         <td id="T_b0d5fc98_f050_11e9_88dd_4889e7b024derow2_col0" class="data row2 col0" >0.00128628</td>
#                         <td id="T_b0d5fc98_f050_11e9_88dd_4889e7b024derow2_col1" class="data row2 col1" >0.30835</td>
#             </tr>
#             <tr>
#                         <th id="T_b0d5fc98_f050_11e9_88dd_4889e7b024delevel0_row3" class="row_heading level0 row3" >bathrooms</th>
#                         <td id="T_b0d5fc98_f050_11e9_88dd_4889e7b024derow3_col0" class="data row3 col0" >0.00516023</td>
#                         <td id="T_b0d5fc98_f050_11e9_88dd_4889e7b024derow3_col1" class="data row3 col1" >0.525138</td>
